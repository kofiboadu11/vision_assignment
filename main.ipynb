# %%
# %pip install roboflow
# %pip install ultralytics
# Out:
# ...
#      ---------------------------------------- 0.0/60.9 kB ? eta -:--:--
#      ------------------- ------------------ 30.7/60.9 kB 660.6 kB/s eta 0:00:01
#      -------------------------------------- 60.9/60.9 kB 817.7 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/13.1 MB ? eta -:--:--
#    ---------------------------------------- 0.1/13.1 MB 2.2 MB/s eta 0:00:06
#     --------------------------------------- 0.3/13.1 MB 3.4 MB/s eta 0:00:04
#    - -------------------------------------- 0.5/13.1 MB 3.9 MB/s eta 0:00:04
#    -- ------------------------------------- 0.7/13.1 MB 4.2 MB/s eta 0:00:03
#    -- ------------------------------------- 1.0/13.1 MB 4.1 MB/s eta 0:00:03
#    --- ------------------------------------ 1.2/13.1 MB 4.6 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.5/13.1 MB 4.8 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.8/13.1 MB 4.8 MB/s eta 0:00:03
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="3qpmUB0qcZ97MjPmowdx")
project = rf.workspace("roboflow-universe-projects").project("basketball-players-fy4c2")
version = project.version(25)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Basketball-Players-25 in yolov8:: 100%|██████████| 2404/2404 [00:00<00:00, 2945.20it/s]

# %%
import torch

# Check if CUDA is available
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"CUDA version: {torch.version.cuda}")
print(f"GPU device: {torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'No GPU'}")
print(f"Number of GPUs: {torch.cuda.device_count()}")
# Out:
# CUDA available: True
# CUDA version: 11.8
# GPU device: NVIDIA GeForce RTX 4070
# Number of GPUs: 1

# %%
from ultralytics import YOLO
model=YOLO("basketball_predictor_V3.pt")
results=model.predict("input_videos/video_1.mp4",save=True)
print(results)
print("================")
for box in results[0].boxes:
    print(box)
# Out:
# WARNING
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/117) c:\Users\Owner\vision_project\input_videos\video_1.mp4: 384x640 1 Ball, 1 Clock, 1 Hoop, 1 Overlay, 8 Players, 2 Refs, 1 Scoreboard, 33.5ms
# video 1/1 (frame 2/117) c:\Users\Owner\vision_project\input_videos\video_1.mp4: 384x640 1 Ball, 1 Clock, 1 Hoop, 1 Overlay, 10 Players, 2 Refs, 1 Scoreboard, 35.8ms
# ...
